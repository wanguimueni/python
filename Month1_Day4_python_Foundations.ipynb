# %% [markdown]
# <a href="https://colab.research.google.com/github/wanguimueni/python_month_1/blob/main/Month1_Day4_python_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
    print("hello")

name = input("what is your name")
hello ()
print (name)
# Out:
# what is your namejun
# hello
# jun

# %%
def hello (to):
    print("hello,", to)

name = input("what is your name")
hello (name)
# Out:
# what is your nameJun
# hello, Jun

# %%
def hello (to='beautiful'):
    print("hello,", to)

name = input("what is your name")
hello (name)
hello ()
# Out:
# what is your nameJUN
# hello, JUN
# hello, beautiful
