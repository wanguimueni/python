# %% [markdown]
# <a href="https://colab.research.google.com/github/wanguimueni/python_month_1/blob/main/Month1_Day4.1_python_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#integers
x=input("what's x for you? ")
y=input("what's y for you? ")
print (x+y)
# Out:
# what's x for you? 4
# what's y for you? 2
# 42

# %%
#integers
x=input("what's x for you? ")
y=input("what's y for you? ")
z=int(x)+int(y)
print (z)
# Out:
# what's x for you? 2556
# what's y for you? 54554
# 57110

# %%
#integers
x=float(input("what's x for you? "))
y=float(input("what's y for you? "))
z=x*y
print (f"{z:,}")
# Out:
# what's x for you? 25
# what's y for you? 26
# 650.0

# %%
#integers
x=float(input("what's x for you? "))
y=float(input("what's y for you? "))
z=x*y
print (f"{z:,.2f}")
# Out:
# what's x for you? 256.32
# what's y for you? 454.2020
# 116,421.06
